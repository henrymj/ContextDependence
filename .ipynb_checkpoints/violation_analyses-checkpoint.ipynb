# %%
from glob import glob
from os import path

# %matplotlib inline
from utils import full_passed_turkers, DATA_DIR, violation_analysis

# %%
# get the various data files to analysis
condition_files = glob(path.join(DATA_DIR, '*'))
condition_files = [filey for filey in condition_files if 'Matzke' not in filey]
condition_files.sort()
condition_files += ['Data/DataMatzke.xlsx'] #append Matzke data to keep preprint's order

# %%
#for each data file, analyze, show the results, and save the images.
for condition_file in condition_files:
    _ = violation_analysis(condition_file, save_results=True, show_imgs=True, verbose=False)
# Out:
# ********************************************************************************
# BtwnSubjAuditory1
# ********************************************************************************
# BtwnSubjAuditory2
# ********************************************************************************
# BtwnSubjStimSelec
# ********************************************************************************
# BtwnSubjVisual1
# ********************************************************************************
# BtwnSubjVisual2
# ********************************************************************************
# Deadline1300ms
# ********************************************************************************
# Deadline1500ms
# ********************************************************************************
# Deadline1700ms
# ********************************************************************************
# Deadline2300ms
# ********************************************************************************
# ...
